# %%
import pandas as pd
import numpy as np

# %%
## test test test


#I created the citibike_station_info.csv file using data from url: https://feeds.citibikenyc.com/stations/stations.json
# Please run the code below to view the data frame

fname = 'citibike_station_info.csv'
df_cb = pd.read_csv(fname)
df_cb.head(20)   #change the numbers of rows you want to view
# Out:
#     Station_id                   Station_Name                       Location  \
# 0           72               W 52 St & 11 Ave               W 52 St & 11 Ave
# 1           79       Franklin St & W Broadway       Franklin St & W Broadway
# 2           82         St James Pl & Pearl St         St James Pl & Pearl St
# 3           83  Atlantic Ave & Fort Greene Pl  Atlantic Ave & Fort Greene Pl
# 4          116                W 17 St & 8 Ave                W 17 St & 8 Ave
# 5          119       Park Ave & St Edwards St       Park Ave & St Edwards St
# 6          120    Lexington Ave & Classon Ave    Lexington Ave & Classon Ave
# 7          127          Barrow St & Hudson St          Barrow St & Hudson St
# 8          128       MacDougal St & Prince St       MacDougal St & Prince St
# 9          137          E 56 St & Madison Ave          E 56 St & Madison Ave
# 10         143      Clinton St & Joralemon St      Clinton St & Joralemon St
# ...
